# %%
import pandas as pd

file_path = "/content/homicideinenglandandwalesappendixtablesyemar2024.xlsx"  # creating a var instead of directly loading it so it can be loaded with a specific table

#df = pd.read_csv("/content/Crime_Aged under 16.csv")
#df.head()

# %%
df3 = pd.read_csv("/content/Locations of crime.csv")
df3.head()
# Out:
#            Area Name  Latitude  Longitude Police Force Area code  \
# 0  England and Wales   52.3555    -1.1743              K04000001
# 1            England   52.3555    -1.1743              E92000001
# 2         North East   54.7753    -1.5849              E12000001
# 3          Cleveland   54.5742    -1.2348              E23000013
# 4             Durham   54.7753    -1.5849              E23000008
#
#   Police Force Area name  Apr 2013 to Mar 2014  Apr 2014 to Mar 2015  \
# 0      ENGLAND AND WALES                   520                   504
# 1                ENGLAND                   504                   478
# 2            North East                     26                    25
# 3              Cleveland                     7                     5
# 4                 Durham                     4                     1
#
#    Apr 2015 to Mar 2016  Apr 2016 to Mar 2017  Apr 2017 to Mar 2018  \
# 0                   538                   689                   697
# ...

# %%
# dropping the columns so i only have the needed lat and lon columns for the map function
df_new = df3.drop(columns=['Police Force Area code',	'Police Force Area name',	'Apr 2013 to Mar 2014',	'Apr 2014 to Mar 2015',	'Apr 2015 to Mar 2016',	'Apr 2016 to Mar 2017',	'Apr 2017 to Mar 2018',	'Apr 2018 to Mar 2019',	'Apr 2019 to Mar 2020',	'Apr 2020 to Mar 2021',	'Apr 2021 to Mar 2022',	'Apr 2022 to Mar 2023',	'Apr 2023 to Mar 2024'])

# %%
df_new.head()
# Out:
#            Area Name  Latitude  Longitude
# 0  England and Wales   52.3555    -1.1743
# 1            England   52.3555    -1.1743
# 2         North East   54.7753    -1.5849
# 3          Cleveland   54.5742    -1.2348
# 4             Durham   54.7753    -1.5849

# %%
df_new.to_csv(r'/content/Lat and Lon locations.csv', index = False)

# %%
df.replace('[x]', 0, inplace=True) # changing all the weird values to represent nothing with 0

# %%
df.head() # sampling to see if change worked which it did
# Out:
#   Sex of victim                  Victim acquainted with suspect  \
# 0          Male                  Victim acquainted with suspect
# 1          Male                  Victim acquainted with suspect
# 2          Male                  Victim acquainted with suspect
# 3          Male  Victim not known to be acquainted with suspect
# 4          Male  Victim not known to be acquainted with suspect
#
#   Relationship to principal suspect Apr 2013 to Mar 2014_count  \
# 0                   Son or daughter                         10
# 1  Other family/friend/acquaintance                          2
# 2                            Total                          12
# 3                          Stranger                          2
# 4            Relationship not known                          0
#
#   Apr 2014 to Mar 2015\n[note 17]_count Apr 2015 to Mar 2016_count  \
# 0                                    21                          7
# ...

# %%
df.to_csv(r'/content/Crime Aged under 16.csv', index=False) # saving this file now its fixed

# %%
df2 = pd.read_excel(file_path, sheet_name='Table 24', skiprows=7)
df2.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/reader/workbook.py:118: UserWarning: Print area cannot be set to Defined name: 'Worksheet 16'!$A:$N.
#   warn(f"Print area cannot be set to Defined name: {defn.value}.")
#   Police Force Area code Police Force Area name  Apr 2013 to Mar 2014  \
# 0              K04000001      ENGLAND AND WALES                   520
# 1              E92000001                ENGLAND                   504
# 2              E12000001            North East                     26
# 3              E23000013              Cleveland                     7
# 4              E23000008                 Durham                     4
#
#    Apr 2014 to Mar 2015  Apr 2015 to Mar 2016  Apr 2016 to Mar 2017  \
# 0                   504                   538                   689
# 1                   478                   505                   655
# 2                    25                    18                    27
# ...

# %%
df2.to_csv(r'/content/Locations of crime.csv', index = False)
